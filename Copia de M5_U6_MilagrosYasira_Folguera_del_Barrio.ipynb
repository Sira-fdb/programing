# %% [markdown]
# En el siguiente notebook vamos a trabajar con PySpark. En él, vamos a usar las transformaciones y las acciones para analizar un pequeño conjunto de datos.
#
# El primer paso que debemos dar es conectar Google Colab con nuestro Google Drive. Para ello, lanzaremos el siguiente trozo de código.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# Una vez hemos conectado Google Drive, pasamos a instalar Apache Spark en nuestro notebook. En concreto, vamos a trabajar con la versión 3.5.0.

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# !wget -q http://apache.mirrors.pair.com/spark/spark-3.5.0/spark-3.5.0-bin-hadoop3.tgz

# %%
# !ls
# Out:
# drive  sample_data  spark-3.5.0-bin-hadoop3.tgz

# %%
# !tar xf spark-3.5.0-bin-hadoop3.tgz

# %% [markdown]
# Además de la instalación habitual, hay un paso más que debemos dar, y es la instalación de la librería *findspark*. Esta librería nos permitirá encontrar la instalación de Apache Spark en nuestro sistema.
#
# Establecemos también un par de variables de entorno.

# %%
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.0-bin-hadoop3"

# %%
import findspark
findspark.init()

# %%
findspark.find()
# Out:
# '/content/spark-3.5.0-bin-hadoop3'

# %% [markdown]
# Una vez tenemos instalado nuestro framework, es momento de crear nuestra variable SparkSession, de la cual parten la mayoría de funcionalidades de SparkSQL

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
        .master("local")\
        .appName("Pyspark_SQL")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://564bdbde34e1:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Pyspark_SQL</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Lectura de datos

# %% [markdown]
# Ahora sí, podemos comenzar a trabajar con SparkSQL. Comenzaremos leyendo nuestro conjunto de datos, el cual contiene información de valoraciones de restaurantes.

# %%
# !pwd
# Out:
# /content

# %%
import pandas as pd

data_path = '/content/drive/MyDrive/TokioSchool/'

data = spark.read.options(inferSchema='True',delimiter=',', header=True).csv (data_path + 'CSV_stocks_2021.csv')

# %%
data
# Out:
# DataFrame[ticker: string, open: double, high: double, low: double, close: double, volume: int, dividends: double, stock splits: int, date: date, ccy: string]

# %% [markdown]
# ### Análisis estadísico

# %%
data.printSchema()
# Out:
# root
#  |-- ticker: string (nullable = true)
#  |-- open: double (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: double (nullable = true)
#  |-- close: double (nullable = true)
#  |-- volume: integer (nullable = true)
#  |-- dividends: double (nullable = true)
#  |-- stock splits: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- ccy: string (nullable = true)

# %% [markdown]
# # Ejercicio: Aprendizaje supervisado

# %% [markdown]
# Obtención de datos
#
# *   a) Filtraremos las filas con valor ‘BA’ en la columna ‘ticker’

# %%
# Filtraremos las filas que correspondan con el valor ‘HON’ de la columna ‘ticker’
data.filter(data.ticker == 'BA').show()
# Out:
# +------+------------------+------------------+------------------+------------------+--------+---------+------------+----------+---+
# |ticker|              open|              high|               low|             close|  volume|dividends|stock splits|      date|ccy|
# +------+------------------+------------------+------------------+------------------+--------+---------+------------+----------+---+
# |    BA|216.24000549316406|216.89999389648438| 212.6999969482422|214.05999755859375|10487600|      0.0|           0|2020-12-31|USD|
# |    BA|             210.0| 210.1999969482422|202.49000549316406|202.72000122070312|21225600|      0.0|           0|2021-01-04|USD|
# |    BA|204.74000549316406|213.35000610351562|204.60000610351562| 211.6300048828125|19338300|      0.0|           0|2021-01-05|USD|
# |    BA|210.22000122070312|215.61000061035156|209.33999633789062|211.02999877929688|16202200|      0.0|           0|2021-01-06|USD|
# |    BA|213.38999938964844|216.60000610351562|211.77999877929688| 212.7100067138672|14474100|      0.0|           0|2021-01-07|USD|
# |    BA|213.61000061035156|214.10000610351562|208.16000366210938|209.89999389648438|14144000|      0.0|           0|2021-01-08|USD|
# |    BA|203.02999877929688|207.77999877929688|201.00999450683594| 206.7899932861328|16770300|      0.0|           0|2021-01-11|USD|
# |    BA|206.64999389648438|209.05999755859375|204.80999755859375|208.41000366210938|12836200|      0.0|           0|2021-01-12|USD|
# |    BA|207.14999389648438| 208.7899932861328|204.85000610351562| 207.2100067138672| 8570500|      0.0|           0|2021-01-13|USD|
# |    BA| 208.7899932861328|214.19000244140625| 208.2100067138672|209.91000366210938|12446800|      0.0|           0|2021-01-14|USD|
# |    BA| 208.9600067138672|            209.25| 204.1999969482422|204.32000732421875|11103300|      0.0|           0|2021-01-15|USD|
# |    BA|206.99000549316406|211.52000427246094|206.52000427246094| 210.7100067138672|11947200|      0.0|           0|2021-01-19|USD|
# |    BA|213.24000549316406|215.58999633789062| 211.2100067138672| 211.4499969482422| 9727000|      0.0|           0|2021-01-20|USD|
# |    BA|211.72000122070312|211.92999267578125|206.33999633789062|207.41000366210938|11091300|      0.0|           0|2021-01-21|USD|
# |    BA| 205.5500030517578| 206.6999969482422|204.27000427246094|205.83999633789062| 7514600|      0.0|           0|2021-01-22|USD|
# |    BA|203.27000427246094| 203.8000030517578| 199.3000030517578|203.36000061035156|14276200|      0.0|           0|2021-01-25|USD|
# |    BA|205.33999633789062|208.35000610351562| 201.7899932861328|202.05999755859375|11011800|      0.0|           0|2021-01-26|USD|
# |    BA|196.89999389648438|199.47000122070312|191.85000610351562|194.02999877929688|20948500|      0.0|           0|2021-01-27|USD|
# |    BA| 198.0500030517578| 200.4199981689453|             196.0|197.22999572753906|10403200|      0.0|           0|2021-01-28|USD|
# |    BA| 198.3000030517578|201.57000732421875| 193.1199951171875|194.19000244140625|13683700|      0.0|           0|2021-01-29|USD|
# +------+------------------+------------------+------------------+------------------+--------+---------+------------+----------+---+
# only showing top 20 rows

# %% [markdown]
# *   b) Importaremos los objetos DecisionTreeClassifier y VectorAssembler del módulo PySpark.ml.

# %%
# Importamos decisiontreeclassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Importamos vectorAssembler
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler

# %% [markdown]
# c) Modificaremos el tipo de datos de las columnas open, low y close a float.

# %%
data2 = data.withColumn("Open",
                                data["Open"]
                                  .cast('float'))
data2.printSchema()

data3 = data2.withColumn("low",
                                data["low"]
                                  .cast('float'))
data3.printSchema()
data4 = data3.withColumn("close",
                                data["close"]
                                  .cast('float'))
data4.printSchema()
# Out:
# root
#  |-- ticker: string (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: double (nullable = true)
#  |-- close: double (nullable = true)
#  |-- volume: integer (nullable = true)
#  |-- dividends: double (nullable = true)
#  |-- stock splits: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- ccy: string (nullable = true)
#
# root
#  |-- ticker: string (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: float (nullable = true)
#  |-- close: double (nullable = true)
#  |-- volume: integer (nullable = true)
#  |-- dividends: double (nullable = true)
#  |-- stock splits: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- ccy: string (nullable = true)
#
# root
#  |-- ticker: string (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: float (nullable = true)
#  |-- close: float (nullable = true)
#  |-- volume: integer (nullable = true)
#  |-- dividends: double (nullable = true)
#  |-- stock splits: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- ccy: string (nullable = true)

# %% [markdown]
# d) Importamos los objetos DecisionTreeClassifier y VectorAssembler del módulo PySpark.ml
# Crearemos una columna ‘features’ utilizando las columnas open, low y close mediante VectorAssembler.

# %%
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.feature import VectorAssembler

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import FloatType

# %%
df = data.withColumn("open", col("open").cast(FloatType()))
df = data.withColumn("low", col("low").cast(FloatType()))
df = data.withColumn("close", col("close").cast(FloatType()))

# %%
assembler = VectorAssembler(inputCols=["open", "low", "close"], outputCol="features")
assembler_df = assembler.transform(df)

# %% [markdown]
# e) Convertiremos la columna ‘ticker’ a tipo numérico, utilizando StringIndexer y llamarla ‘label’.

# %%
# Importamos StringIndexer
from pyspark.ml.feature import StringIndexer
from pyspark.ml import Pipeline

# %%
# # Convertiremos la columna ‘ticker’ a tipo numérico, utilizando StringIndexer y llamarla ‘label’.

from pyspark.ml.feature import StringIndexer

indexer = StringIndexer(inputCol="ticker", outputCol="label")
df_with_label = indexer.fit(assembler_df).transform(assembler_df)
df_with_label.show()
# Out:
# +------+------------------+------------------+------------------+---------+-------+---------+------------+----------+---+--------------------+-----+
# |ticker|              open|              high|               low|    close| volume|dividends|stock splits|      date|ccy|            features|label|
# +------+------------------+------------------+------------------+---------+-------+---------+------------+----------+---+--------------------+-----+
# |   HON|207.45501408335315|209.42141232111007|206.14735745495346|209.12645|1406400|      0.0|           0|2020-12-31|USD|[207.455014083353...| 13.0|
# |   HON|209.26409612607986|209.43123817541044| 202.8929700588177|204.45625|2328900|      0.0|           0|2021-01-04|USD|[209.264096126079...| 13.0|
# |   HON|203.50255708426138| 206.6586329757187|203.50255708426138| 204.9577|2172100|      0.0|           0|2021-01-05|USD|[203.502557084261...| 13.0|
# |   HON|205.93106042557045|210.38495140642195|205.71475541084416|208.69385|2747900|      0.0|           0|2021-01-06|USD|[205.931060425570...| 13.0|
# |   HON|209.31327369732284|210.41445198270796|207.25839100319203|209.03798|2057300|      0.0|           0|2021-01-07|USD|[209.313273697322...| 13.0|
# |   HON|209.22477804904162|209.82453011896777| 204.1809617069155|206.50131|3278900|      0.0|           0|2021-01-08|USD|[209.224778049041...| 13.0|
# |   HON|  204.613559972612|206.09818517407587|204.33826543197534|204.85936|2938900|      0.0|           0|2021-01-11|USD|[204.613559972612...| 13.0|
# |   HON|  204.367783872409| 205.9605617566175|201.81145998195402|205.37065|2498800|      0.0|           0|2021-01-12|USD|[204.367783872409...| 13.0|
# |   HON|  204.780710862364| 205.1149949615185|202.93229172186355|203.54189|2145100|      0.0|           0|2021-01-13|USD|[204.780710862364...| 13.0|
# |   HON|204.54474810663825|206.25552005813464|203.69919622290033|205.10518|3661500|      0.0|           0|2021-01-14|USD|[204.544748106638...| 13.0|
# |   HON|204.04330969253792|204.36776719848436|    201.7524539705|202.50952|3887500|      0.0|           0|2021-01-15|USD|[204.043309692537...| 13.0|
# |   HON| 204.7414004554059|205.25265322179186| 202.9814655406593|203.28625|2656300|      0.0|           0|2021-01-19|USD|[204.741400455405...| 13.0|
# |   HON| 204.4267604669998|205.16415981146147|203.19776155956373|204.58408|2452400|      0.0|           0|2021-01-20|USD|[204.426760466999...| 13.0|
# |   HON|203.38457127629206|204.31860744308085|201.65414621989987|201.78195|2705100|      0.0|           0|2021-01-21|USD|[203.384571276292...| 13.0|
# |   HON| 200.8282604869766|201.02491232627204| 198.0064836217491|198.85204|3502700|      0.0|           0|2021-01-22|USD|[200.828260486976...| 13.0|
# |   HON|197.95731446101044|199.15681863147958|196.73815710917054|198.47841|4737700|      0.0|           0|2021-01-25|USD|[197.957314461010...| 13.0|
# |   HON|200.41529910872143|201.32968206461314|197.60334910836625|  197.682|2201900|      0.0|           0|2021-01-26|USD|[200.415299108721...| 13.0|
# |   HON|194.78159101389213|197.38706285147768|193.22813450230996|196.03026|4108600|      0.0|           0|2021-01-27|USD|[194.781591013892...| 13.0|
# |   HON|197.24941031607628|201.89995313608185|196.27605275101863|199.43211|3731700|      0.0|           0|2021-01-28|USD|[197.249410316076...| 13.0|
# |   HON| 193.2084624142251|197.56404251420506| 191.2814004531731|192.08762|4635100|      0.0|           0|2021-01-29|USD|[193.208462414225...| 13.0|
# +------+------------------+------------------+------------------+---------+-------+---------+------------+----------+---+--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# # Ejercicio: Aprendizaje supervisado

# %% [markdown]
# a) Crearemos el objeto DecisionTreeClassifier

# %%
# Importamos decisiontreeclassifier y numpy
from sklearn.tree import DecisionTreeClassifier
import numpy as np
from sklearn.model_selection import train_test_split
from pyspark.ml.feature import IndexToString

# %%
# Entrenamos el modelo
(train, test) = df_with_label.randomSplit([0.2, 0.8])

# %%
# Crear el objeto IndexToString
index_to_string = IndexToString(inputCol="label", outputCol="original_ticker")

# Transformar las predicciones para obtener los valores originales de 'ticker'
df_with_original_ticker = index_to_string.transform(df_with_label)

# %%
dtc = DecisionTreeClassifier(featuresCol="features", labelCol="label")
dtc = dtc.fit(train)

# %%
#Uniremos mediante un inner join, el dataframe con las predicciones y el que contiene los valores reestablecidos de la columna ‘ticker’.
pred = dtc.transform(test)
finalResult = pred.join(df_with_original_ticker, on="ticker", how="inner")
