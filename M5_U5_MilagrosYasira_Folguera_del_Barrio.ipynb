# %% [markdown]
# En el siguiente notebook vamos a trabajar con PySpark. En él, vamos a usar las transformaciones y las acciones para analizar un pequeño conjunto de datos.
#
# El primer paso que debemos dar es conectar Google Colab con nuestro Google Drive. Para ello, lanzaremos el siguiente trozo de código.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# Una vez hemos conectado Google Drive, pasamos a instalar Apache Spark en nuestro notebook. En concreto, vamos a trabajar con la versión 3.5.0.

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# !wget -q http://apache.mirrors.pair.com/spark/spark-3.5.0/spark-3.5.0-bin-hadoop3.tgz

# %%
# !ls
# Out:
# drive  sample_data  spark-3.5.0-bin-hadoop3.tgz

# %%
# !tar xf spark-3.5.0-bin-hadoop3.tgz

# %% [markdown]
# Además de la instalación habitual, hay un paso más que debemos dar, y es la instalación de la librería *findspark*. Esta librería nos permitirá encontrar la instalación de Apache Spark en nuestro sistema.
#
# Establecemos también un par de variables de entorno.

# %%
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.0-bin-hadoop3"

# %%
import findspark
findspark.init()

# %%
findspark.find()
# Out:
# '/content/spark-3.5.0-bin-hadoop3'

# %% [markdown]
# Una vez tenemos instalado nuestro framework, es momento de crear nuestra variable SparkSession, de la cual parten la mayoría de funcionalidades de SparkSQL

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
        .master("local")\
        .appName("Pyspark_SQL")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://d08b05c01aa8:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Pyspark_SQL</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Lectura de datos

# %% [markdown]
# Ahora sí, podemos comenzar a trabajar con SparkSQL. Comenzaremos leyendo nuestro conjunto de datos, el cual contiene información de valoraciones de restaurantes.

# %%
# !pwd
# Out:
# /content

# %%
import pandas as pd

data_path = '/content/drive/MyDrive/TokioSchool/'

data = spark.read.options(inferSchema='True',delimiter=',', header=True).csv (data_path + 'CSV_stocks_2021.csv')

# %%
data
# Out:
# DataFrame[ticker: string, open: double, high: double, low: double, close: double, volume: int, dividends: double, stock splits: int, date: date, ccy: string]

# %% [markdown]
# ### Análisis estadísico

# %%
data.printSchema()
# Out:
# root
#  |-- ticker: string (nullable = true)
#  |-- open: double (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: double (nullable = true)
#  |-- close: double (nullable = true)
#  |-- volume: integer (nullable = true)
#  |-- dividends: double (nullable = true)
#  |-- stock splits: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- ccy: string (nullable = true)

# %% [markdown]
# Obtención de datos
#
# *   a) Filtraremos las filas que correspondan con el valor ‘HON’ de la columna ‘ticker’

# %%
# Filtraremos las filas que correspondan con el valor ‘HON’ de la columna ‘ticker’
data.filter(data.ticker == 'HON').show()
# Out:
# +------+------------------+------------------+------------------+------------------+-------+---------+------------+----------+---+
# |ticker|              open|              high|               low|             close| volume|dividends|stock splits|      date|ccy|
# +------+------------------+------------------+------------------+------------------+-------+---------+------------+----------+---+
# |   HON|207.45501408335315|209.42141232111007|206.14735745495346|209.12644958496094|1406400|      0.0|           0|2020-12-31|USD|
# |   HON|209.26409612607986|209.43123817541044| 202.8929700588177| 204.4562530517578|2328900|      0.0|           0|2021-01-04|USD|
# |   HON|203.50255708426138| 206.6586329757187|203.50255708426138|204.95770263671875|2172100|      0.0|           0|2021-01-05|USD|
# |   HON|205.93106042557045|210.38495140642195|205.71475541084416|   208.69384765625|2747900|      0.0|           0|2021-01-06|USD|
# |   HON|209.31327369732284|210.41445198270796|207.25839100319203|209.03797912597656|2057300|      0.0|           0|2021-01-07|USD|
# |   HON|209.22477804904162|209.82453011896777| 204.1809617069155|206.50131225585938|3278900|      0.0|           0|2021-01-08|USD|
# |   HON|  204.613559972612|206.09818517407587|204.33826543197534|204.85935974121094|2938900|      0.0|           0|2021-01-11|USD|
# |   HON|  204.367783872409| 205.9605617566175|201.81145998195402| 205.3706512451172|2498800|      0.0|           0|2021-01-12|USD|
# |   HON|  204.780710862364| 205.1149949615185|202.93229172186355|203.54188537597656|2145100|      0.0|           0|2021-01-13|USD|
# |   HON|204.54474810663825|206.25552005813464|203.69919622290033| 205.1051788330078|3661500|      0.0|           0|2021-01-14|USD|
# |   HON|204.04330969253792|204.36776719848436|    201.7524539705|  202.509521484375|3887500|      0.0|           0|2021-01-15|USD|
# |   HON| 204.7414004554059|205.25265322179186| 202.9814655406593| 203.2862548828125|2656300|      0.0|           0|2021-01-19|USD|
# |   HON| 204.4267604669998|205.16415981146147|203.19776155956373|204.58407592773438|2452400|      0.0|           0|2021-01-20|USD|
# |   HON|203.38457127629206|204.31860744308085|201.65414621989987|201.78195190429688|2705100|      0.0|           0|2021-01-21|USD|
# |   HON| 200.8282604869766|201.02491232627204| 198.0064836217491|198.85203552246094|3502700|      0.0|           0|2021-01-22|USD|
# |   HON|197.95731446101044|199.15681863147958|196.73815710917054|198.47840881347656|4737700|      0.0|           0|2021-01-25|USD|
# |   HON|200.41529910872143|201.32968206461314|197.60334910836625| 197.6820068359375|2201900|      0.0|           0|2021-01-26|USD|
# |   HON|194.78159101389213|197.38706285147768|193.22813450230996|196.03025817871094|4108600|      0.0|           0|2021-01-27|USD|
# |   HON|197.24941031607628|201.89995313608185|196.27605275101863|199.43211364746094|3731700|      0.0|           0|2021-01-28|USD|
# |   HON| 193.2084624142251|197.56404251420506| 191.2814004531731|192.08761596679688|4635100|      0.0|           0|2021-01-29|USD|
# +------+------------------+------------------+------------------+------------------+-------+---------+------------+----------+---+
# only showing top 20 rows

# %% [markdown]
# *   b) Extraeremos la columna ‘open’ y la convertiremos en un array unidimensional **usando** Numpy.

# %%
# importamos la biblioteca de numpy como np
import numpy as np

# %%
# transformamos un PySpark dataframe a Pandas para poder utilizar Python
pandas_data = data.toPandas()

# %%
# extraemos la columna open y la convertimos en un array unidimensional
data_array = np.array(pandas_data['open']).ravel()
print(data_array)
# Out:
# [207.45501408 209.26409613 203.50255708 ...  28.22999954  28.28000069
#   28.17000008]

# %% [markdown]
# *   c) Dividiremos el array en dos para comparar dos periodos y determinar si se ha producido un cambio significativo.

# %%
# dividimos el array en 2 para poder comparar dos periodos
data_array_split = np.array_split(data_array, 2)
data_array_0 = data_array_split[0].astype(float)
data_mean_0 = np.mean(data_array_0)
data_array_1 = data_array_split[1].astype(float)
data_mean_1 = np.mean(data_array_1)
# mostramos los resultados
print(data_array_0)
print(data_array_1)
# Out:
# [207.45501408 209.26409613 203.50255708 ...  38.53870413  39.29360605
#   40.03882752]
# [38.71291254 39.63235014 39.81623245 ... 28.22999954 28.28000069
#  28.17000008]

# %%
# mostramos las medias de los dos arrays
print(data_mean_0)
print(data_mean_1)
# Out:
# 406.42411510557037
# 149.69845340250652

# %% [markdown]
# Según los datos obtenidos, sí hay un cambio significativo

# %% [markdown]
# * d) Dividiremos el array en dos para comparar dos periodos y determinar si existe correlación entre ellos en la misma
# categoría.

# %%
# importamos el módulo Scikit-Learn
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# preparamos una secuencia del 1 al 1000 para representarla en nuestro gráfico como eje X
contador = []
puntos = 1000
for a in range(puntos):
  contador.append(a)

# %%
# preparamos dos arrays unidimensionales cada uno con un periodo
# data_array_0 = np.delete(data_array_0, 0)
X_train = np.array(data_array_0).reshape(-1, 1)
y_train = np.array(data_array_1).reshape(-1, 1)
print (X_train)
print (y_train)
# Out:
# [[207.45501408]
#  [209.26409613]
#  [203.50255708]
#  ...
#  [ 38.53870413]
#  [ 39.29360605]
#  [ 40.03882752]]
# [[38.71291254]
#  [39.63235014]
#  [39.81623245]
#  ...
#  [28.22999954]
#  [28.28000069]
#  [28.17000008]]

# %%
# entrenamos un modelo de regresión lineal utiizando el array que contiene el primer periodo
regr = linear_model.LinearRegression()
regr.fit(X_train,y_train)
X_train.reshape(-1,1)
y_train.reshape(-1,1)
# Out:
# array([[38.71291254],
#        [39.63235014],
#        [39.81623245],
#        ...,
#        [28.22999954],
#        [28.28000069],
#        [28.17000008]])

# %%
# calculamos el coeficiente de correlación
print(regr.coef_)
# Out:
# [[-0.00414641]]

# %% [markdown]
# como el valor de la correlación es muy pequeño se puede decir que no hay correlación
